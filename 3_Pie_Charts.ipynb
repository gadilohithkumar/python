# %% [markdown]
# # Pei Plot/Charts

# %% [markdown]
# A pie chart shows how a total amount is divided between levels of a categorical variable as a circle divided into radial slices. Each categorical value corresponds with a single slice of the circle, and the size of each slice (both in area and arc length) indicates what proportion of the whole each category level takes.

# %% [markdown]
# ### When you should use a pie chart
# Pie charts have a fairly narrow use-case that is encapsulated particularly well by its definition. In order to use a pie chart, you must have some kind of whole amount that is divided into a number of distinct parts. Your primary objective in a pie chart should be to compare each group’s contribution to the whole, as opposed to comparing groups to each other. If the above points are not satisfied, the pie chart is not appropriate, and a different plot type should be used instead.

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# <h3 style = "color:red"> Recommended to use when we have 5 or less values to plot </h3>

# %% [markdown]
# ### 1. Plotting the Pie Chart

# %%
slices = [30, 40, 20, 50] #sum needs not be 100

# %%
plt.pie(slices)
plt.show()

# %% [markdown]
# ### 2. Adding labels to the pie chart

# %%
labels = ['thirty','fourty', 'twenty','fifty']
plt.pie(slices, labels=labels)
plt.show()

# %% [markdown]
# ### 3. setting edge color

# %%
plt.pie(slices, labels=labels, wedgeprops={'edgecolor':'black'})
plt.show()

# %% [markdown]
# ### 4. setting color of the slices

# %%
color = ['blue','red','yellow','green']

#hexadecimal color codes can also be used
plt.pie(slices, labels=labels, colors=color, wedgeprops={'edgecolor':'black'})
plt.show()

# %% [markdown]
# ### 5. plotting real world data

# %%
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']

slices = [59219, 55466, 47544, 36443, 35917]

# %%
plt.pie(slices, labels=labels, wedgeprops={'edgecolor':'black'})
plt.show()

# %% [markdown]
# ### 6. Exploding the slice

# %%
explode = [0, 0, 0, 0.1, 0]

plt.pie(slices, labels=labels, explode=explode, wedgeprops={'edgecolor':'black'})
plt.show()

# %% [markdown]
# ### 7. adding shadow to the chart

# %%
plt.pie(slices, labels=labels, explode=explode, shadow=True, wedgeprops={'edgecolor':'black'})
plt.show()

# %% [markdown]
# ### 8. setting the starting angle

# %%
plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=90, wedgeprops={'edgecolor':'black'})
plt.show()

# %% [markdown]
# ### 9. displaying percentage of each slices

# %%
plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=70, autopct="%0.1f%%", wedgeprops={'edgecolor':'black'})
plt.show()

# %% [markdown]
# ## **Show Your Creativity**
#
#
# ---
# ### **Covid 19 India Data as on 5th Sept 2020**

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
data = pd.read_csv('Covid_19.csv')

# %%
data.head()
# Out:
#   State               last_updated  population tested__last_updated  \
# 0    AN  2020-09-05T22:09:31+05:30      397000             9/4/2020
# 1    AP  2020-09-05T20:15:29+05:30    52221000             9/5/2020
# 2    AR  2020-09-06T00:53:37+05:30     1504000             9/5/2020
# 3    AS  2020-09-05T22:39:27+05:30    34293000             9/5/2020
# 4    BR  2020-09-05T18:43:27+05:30   119520000             9/5/2020
#
#    total__confirmed  total__deceased  total__recovered  total__tested
# 0              3292             50.0              2904          37825
# 1            487331           4347.0            382104        4035317
# 2              4914              8.0              3381         183390
# 3            123923            352.0             95061        2471274
# 4            145861            750.0            128376        3871733
